# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('1year.csv')
df2 = pd.read_csv('2year.csv')
df3 = pd.read_csv('3year.csv')
df4 = pd.read_csv('4year.csv')
df5 = pd.read_csv('5year.csv')
# Out:
# C:\Users\Akshay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,1,2,5,6,8,9,10,13,17,21,23,24,28,34,35,37,47,50,54,56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Akshay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (14,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Akshay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,1,2,5,6,7,9,10,13,14,15,16,17,21,23,24,25,28,33,34,35,37,47,49,50,56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0   0.20055  0.37951  0.39641  2.0472   32.351  0.38825   0.24976   1.3305
# 1   0.20912  0.49988  0.47225  1.9447   14.786        0   0.25834  0.99601
# 2   0.24866  0.69592  0.26713  1.5548  -1.1523        0   0.30906  0.43695
# 3  0.081483  0.30734  0.45879  2.4928   51.952  0.14988  0.092704   1.8661
# 4   0.18732  0.61323   0.2296  1.4063  -7.3128  0.18732   0.18732   0.6307
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924   8.416  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300         0  4.1486  3.2732
# 2   1.309  0.30408  ...  0.241140  0.81774  0.76599   0.69484  4.9909   3.951
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598         0  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515   0.12444  6.3985  4.3158
#
#     Attr62  Attr63  Attr64  class
# ...

# %%
df1.shape
# Out:
# (7012, 65)

# %%
def fun_view():
    
    null_values = df1.apply(lambda x:x.isnull().sum())
    
    blank_char = df1.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df1.apply(lambda x:round((x.isin(['?']).sum()/df1.shape[0])*100, 2))
    
    unique_values = df1.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         3        0.04           6618
# Attr2             0         3        0.04           6593
# Attr3             0         3        0.04           6691
# Attr4             0        30        0.43           6274
# Attr5             0         8        0.11           6806
# Attr6             0         3        0.04           4202
# Attr7             0         3        0.04           6661
# Attr8             0        25        0.36           6671
# Attr9             0         1        0.01           5500
# Attr10            0         3        0.04           6621
# Attr11            0        38        0.54           6635
# Attr12            0        30        0.43           6713
# Attr13            0         0        0.00           6605
# Attr14            0         3        0.04           6661
# Attr15            0         2        0.03           6678
# ...

# %%
df1[df1['Attr1'] == '0']
# Out:
#      Attr1    Attr2      Attr3    Attr4     Attr5      Attr6      Attr7  \
# 82       0  0.21671    0.47279   36.788         ?   0.019568  -0.025266
# 325      0  0.73793    0.25685   1.4805    54.064    0.05951   0.060691
# 644      0        0          0        ?         0     303.67     186.43
# 825      0  0.75519  -0.056859  0.90446   -79.004   0.010872    0.01732
# 1232     0        0          0        ?         0          0      19.34
# 1337     0  0.45806   0.000935   1.0038   -55.916          0   0.013109
# 1411     0  -2.4218          0        ?         0          0     91.812
# 1650     0  0.52292   -0.27784  0.44799   -326.42          0   -0.10061
# 1677     0        0          0        ?         0          0     203.45
# 1715     0        0          0        ?         0   0.018089     72.364
# 1796     0  0.73792   0.059384   1.2375   -9.8752          0   0.065091
# 1799     0  0.65183    0.16626   1.2582   -30.396          0   0.064588
# ...

# %%
df1 = df1.replace('?', np.nan)
df1 = df1.astype(float)
df1 = df1.replace(np.nan, df1.mean())

# %%
df1[df1['Attr1'] == 0]
# Out:
#       Attr1     Attr2     Attr3     Attr4         Attr5       Attr6  \
# 82      0.0   0.21671  0.472790  36.78800   -263.666723    0.019568
# 325     0.0   0.73793  0.256850   1.48050     54.064000    0.059510
# 644     0.0   0.00000  0.000000   2.63079      0.000000  303.670000
# 825     0.0   0.75519 -0.056859   0.90446    -79.004000    0.010872
# 1232    0.0   0.00000  0.000000   2.63079      0.000000    0.000000
# 1337    0.0   0.45806  0.000935   1.00380    -55.916000    0.000000
# 1411    0.0  -2.42180  0.000000   2.63079      0.000000    0.000000
# 1650    0.0   0.52292 -0.277840   0.44799   -326.420000    0.000000
# 1677    0.0   0.00000  0.000000   2.63079      0.000000    0.000000
# 1715    0.0   0.00000  0.000000   2.63079      0.000000    0.018089
# 1796    0.0   0.73792  0.059384   1.23750     -9.875200    0.000000
# 1799    0.0   0.65183  0.166260   1.25820    -30.396000    0.000000
# 1919    0.0   0.65926  0.147600   1.64470   -263.666723    0.078839
# ...

# %%
def fun_view():
    
    null_values = df1.apply(lambda x:x.isnull().sum())
    
    blank_char = df1.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df1.apply(lambda x:round((x.isin(['?']).sum()/df1.shape[0])*100, 2))
    
    unique_values = df1.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0         0.0           6618
# Attr2             0         0         0.0           6593
# Attr3             0         0         0.0           6691
# Attr4             0         0         0.0           6274
# Attr5             0         0         0.0           6806
# Attr6             0         0         0.0           4202
# Attr7             0         0         0.0           6661
# Attr8             0         0         0.0           6671
# Attr9             0         0         0.0           5500
# Attr10            0         0         0.0           6621
# Attr11            0         0         0.0           6635
# Attr12            0         0         0.0           6713
# Attr13            0         0         0.0           6605
# Attr14            0         0         0.0           6661
# Attr15            0         0         0.0           6678
# ...

# %%
df2.shape
# Out:
# (10173, 65)

# %%
def fun_view():
    
    null_values = df2.apply(lambda x:x.isnull().sum())
    
    blank_char = df2.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df2.apply(lambda x:round((x.isin(['?']).sum()/df2.shape[0])*100, 2))
    
    unique_values = df2.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         1        0.01           9797
# Attr2             0         1        0.01           9739
# Attr3             0         1        0.01           9813
# Attr4             0        22        0.22           9076
# Attr5             0        24        0.24           9854
# Attr6             0         1        0.01           5588
# Attr7             0         1        0.01           9831
# Attr8             0        18        0.18           9651
# Attr9             0         4        0.04           8600
# Attr10            0         1        0.01           9732
# Attr11            0         1        0.01           9785
# Attr12            0        22        0.22           9787
# Attr13            0        63        0.62           9550
# Attr14            0         1        0.01           9831
# Attr15            0        12        0.12           9750
# ...

# %%
df2 = df2.replace('?', np.nan)
df2 = df2.astype(float)
df2 = df2.replace(np.nan, df2.mean())

# %%
def fun_view():
    
    null_values = df2.apply(lambda x:x.isnull().sum())
    
    blank_char = df2.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df2.apply(lambda x:round((x.isin(['?']).sum()/df2.shape[0])*100, 2))
    
    unique_values = df2.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0         0.0           9685
# Attr2             0         0         0.0           9580
# Attr3             0         0         0.0           9691
# Attr4             0         0         0.0           9076
# Attr5             0         0         0.0           9854
# Attr6             0         0         0.0           5554
# Attr7             0         0         0.0           9721
# Attr8             0         0         0.0           9651
# Attr9             0         0         0.0           8100
# Attr10            0         0         0.0           9583
# Attr11            0         0         0.0           9661
# Attr12            0         0         0.0           9787
# Attr13            0         0         0.0           9550
# Attr14            0         0         0.0           9721
# Attr15            0         0         0.0           9750
# ...

# %%
df3.shape
# Out:
# (10476, 65)

# %%
def fun_view():
    
    null_values = df3.apply(lambda x:x.isnull().sum())
    
    blank_char = df3.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df3.apply(lambda x:round((x.isin(['?']).sum()/df3.shape[0])*100, 2))
    
    unique_values = df3.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0        0.00           9883
# Attr2             0         0        0.00           9784
# Attr3             0         0        0.00           9925
# Attr4             0        18        0.17           9403
# Attr5             0        25        0.24          10161
# Attr6             0         0        0.00           5839
# Attr7             0         0        0.00           9928
# Attr8             0        14        0.13           9916
# Attr9             0         3        0.03           8346
# Attr10            0         0        0.00           9806
# Attr11            0         0        0.00           9907
# Attr12            0        18        0.17          10052
# Attr13            0        42        0.40           9826
# Attr14            0         0        0.00           9928
# Attr15            0         8        0.08          10161
# ...

# %%
df3 = df3.replace('?', np.nan)
df3 = df3.astype(float)
df3 = df3.replace(np.nan, df3.mean())

# %%
def fun_view():
    
    null_values = df3.apply(lambda x:x.isnull().sum())
    
    blank_char = df3.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df3.apply(lambda x:round((x.isin(['?']).sum()/df3.shape[0])*100, 2))
    
    unique_values = df3.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0         0.0           9883
# Attr2             0         0         0.0           9784
# Attr3             0         0         0.0           9925
# Attr4             0         0         0.0           9403
# Attr5             0         0         0.0          10161
# Attr6             0         0         0.0           5839
# Attr7             0         0         0.0           9928
# Attr8             0         0         0.0           9916
# Attr9             0         0         0.0           8346
# Attr10            0         0         0.0           9806
# Attr11            0         0         0.0           9907
# Attr12            0         0         0.0          10052
# Attr13            0         0         0.0           9826
# Attr14            0         0         0.0           9928
# Attr15            0         0         0.0          10005
# ...

# %%
df4.shape
# Out:
# (9539, 65)

# %%
def fun_view():
    
    null_values = df4.apply(lambda x:x.isnull().sum())
    
    blank_char = df4.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df4.apply(lambda x:round((x.isin(['?']).sum()/df4.shape[0])*100, 2))
    
    unique_values = df4.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         1        0.01           9161
# Attr2             0         1        0.01           9082
# Attr3             0         1        0.01           9185
# Attr4             0        42        0.44           8499
# Attr5             0        20        0.21           9260
# Attr6             0         1        0.01           5445
# Attr7             0         1        0.01           9168
# Attr8             0        19        0.20           9131
# Attr9             0         0        0.00           7622
# Attr10            0         1        0.01           9115
# Attr11            0         1        0.01           9191
# Attr12            0        42        0.44           9152
# Attr13            0        21        0.22           9018
# Attr14            0         1        0.01           9168
# Attr15            0         8        0.08           9203
# ...

# %%
df4 = df4.replace('?', np.nan)
df4 = df4.astype(float)
df4 = df4.replace(np.nan, df4.mean())

# %%
def fun_view():
    
    null_values = df4.apply(lambda x:x.isnull().sum())
    
    blank_char = df4.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df4.apply(lambda x:round((x.isin(['?']).sum()/df4.shape[0])*100, 2))
    
    unique_values = df4.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0         0.0           9087
# Attr2             0         0         0.0           8970
# Attr3             0         0         0.0           9095
# Attr4             0         0         0.0           8499
# Attr5             0         0         0.0           9260
# Attr6             0         0         0.0           5422
# Attr7             0         0         0.0           9100
# Attr8             0         0         0.0           9010
# Attr9             0         0         0.0           7622
# Attr10            0         0         0.0           9011
# Attr11            0         0         0.0           9108
# Attr12            0         0         0.0           9152
# Attr13            0         0         0.0           9018
# Attr14            0         0         0.0           9100
# Attr15            0         0         0.0           9105
# ...

# %%
df5.shape
# Out:
# (5427, 65)

# %% [raw]
# df1 = df1.replace('?', np.nan)
# df1 = df1.replace(np.nan, df1.mean())
# df1 = df1.astype(float)

# %%
def fun_view():
    
    null_values = df5.apply(lambda x:x.isnull().sum())
    
    blank_char = df5.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df5.apply(lambda x:round((x.isin(['?']).sum()/df5.shape[0])*100, 2))
    
    unique_values = df5.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         3        0.06           5169
# Attr2             0         3        0.06           5167
# Attr3             0         3        0.06           5211
# Attr4             0        21        0.39           5044
# Attr5             0        10        0.18           5313
# Attr6             0         3        0.06           3222
# Attr7             0         3        0.06           5204
# Attr8             0        18        0.33           5187
# Attr9             0         1        0.02           4522
# Attr10            0         3        0.06           5168
# Attr11            0         3        0.06           5220
# Attr12            0        21        0.39           5225
# Attr13            0         0        0.00           5206
# Attr14            0         3        0.06           5204
# Attr15            0         6        0.11           5232
# ...

# %%
df5 = df5.replace('?', np.nan)
df5 = df5.astype(float)
df5 = df5.replace(np.nan, df5.mean())

# %%
def fun_view():
    
    null_values = df5.apply(lambda x:x.isnull().sum())
    
    blank_char = df5.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df5.apply(lambda x:round((x.isin(['?']).sum()/df5.shape[0])*100, 2))
    
    unique_values = df5.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0         0.0           5169
# Attr2             0         0         0.0           5167
# Attr3             0         0         0.0           5211
# Attr4             0         0         0.0           5044
# Attr5             0         0         0.0           5313
# Attr6             0         0         0.0           3222
# Attr7             0         0         0.0           5204
# Attr8             0         0         0.0           5187
# Attr9             0         0         0.0           4522
# Attr10            0         0         0.0           5168
# Attr11            0         0         0.0           5220
# Attr12            0         0         0.0           5225
# Attr13            0         0         0.0           5206
# Attr14            0         0         0.0           5204
# Attr15            0         0         0.0           5232
# ...

# %%
df = pd.concat([df1, df2, df3, df4, df5], axis = 0, sort= False)
df.shape
# Out:
# (42627, 65)

# %%
def fun_view():
    
    null_values = df.apply(lambda x:x.isnull().sum())
    
    blank_char = df.apply(lambda x:x.isin(['?']).sum())
    
    percent_blank_char = df.apply(lambda x:round((x.isin(['?']).sum()/df.shape[0])*100, 2))
    
    unique_values = df.apply(lambda x:len(x.unique()))
    
    return pd.DataFrame({'null_values':null_values,
                         '? Values':blank_char,'% ? Values':percent_blank_char
                        ,'unique_values':unique_values})

print('Function Information',fun_view.__doc__)
view = fun_view()
display(view)
# Out:
# Function Information None
#         null_values  ? Values  % ? Values  unique_values
# Attr1             0         0         0.0          36792
# Attr2             0         0         0.0          34959
# Attr3             0         0         0.0          36789
# Attr4             0         0         0.0          29786
# Attr5             0         0         0.0          39015
# Attr6             0         0         0.0          23134
# Attr7             0         0         0.0          36818
# Attr8             0         0         0.0          35957
# Attr9             0         0         0.0          24252
# Attr10            0         0         0.0          35093
# Attr11            0         0         0.0          36499
# Attr12            0         0         0.0          37795
# Attr13            0         0         0.0          35976
# Attr14            0         0         0.0          36818
# Attr15            0         0         0.0          36907
# ...

# %%
df['class'] = df['class'].astype(int)
df['class'].value_counts()
# Out:
# 0    40578
# 1     2049
# Name: class, dtype: int64

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
x = df.drop('class', axis = 1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
from imblearn.over_sampling import SMOTE
s=SMOTE(ratio='minority')
x_train,y_train=s.fit_sample(x_train,y_train)
x_test,y_test=s.fit_sample(x_test,y_test)
print(sum(y_train==1))
print(sum(y_train==0))
# Out:
# C:\Users\Akshay\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\Akshay\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# 28378
# 28378

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb_pred = xgb.fit(x_train, y_train).predict(x_test)
print('Training score is',xgb.score(x_train, y_train))
print('Test score is ',xgb.score(x_test, y_test))
print('Accuracy is',accuracy_score(y_test, xgb_pred))
# Out:
# Training score is 0.9341038832898725
# Test score is  0.9220901639344262
# Accuracy is 0.9220901639344262

# %%
print(classification_report(y_test, xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     12200
#            1       0.93      0.91      0.92     12200
#
#     accuracy                           0.92     24400
#    macro avg       0.92      0.92      0.92     24400
# weighted avg       0.92      0.92      0.92     24400

# %%
print(confusion_matrix(y_test, xgb_pred))
# Out:
# [[11362   838]
#  [ 1063 11137]]
